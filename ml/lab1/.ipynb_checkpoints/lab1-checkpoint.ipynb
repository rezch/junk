# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('./steam_games_dataset.csv')
df.head()
# Out:
#      appid                              name         developer  \
# 0      730  Counter-Strike: Global Offensive             Valve
# 1  1172470                      Apex Legends           Respawn
# 2   578080               PUBG: BATTLEGROUNDS  PUBG Corporation
# 3  1623730                          Palworld        Pocketpair
# 4      440                   Team Fortress 2             Valve
#
#          publisher  score_rank  positive  negative  userscore  \
# 0            Valve         NaN   7642084   1173003          0
# 1  Electronic Arts         NaN    668053    326926          0
# 2    KRAFTON, Inc.         NaN   1520457   1037487          0
# 3       Pocketpair         NaN    358266     22443          0
# 4            Valve         NaN   1044264    117208          0
#
#                        owners  average_forever  average_2weeks  \
# 0  100,000,000 .. 200,000,000            33852             708
# 1  100,000,000 .. 200,000,000            10506             496
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   appid            10000 non-null  int64
#  1   name             10000 non-null  str
#  2   developer        9967 non-null   str
#  3   publisher        9946 non-null   str
#  4   score_rank       5 non-null      float64
#  5   positive         10000 non-null  int64
#  6   negative         10000 non-null  int64
#  7   userscore        10000 non-null  int64
#  8   owners           10000 non-null  str
#  9   average_forever  10000 non-null  int64
#  10  average_2weeks   10000 non-null  int64
#  11  median_forever   10000 non-null  int64
#  12  median_2weeks    10000 non-null  int64
#  13  price            10000 non-null  int64
#  14  initialprice     10000 non-null  int64
#  15  discount         10000 non-null  int64
#  16  ccu              10000 non-null  int64
# ...

# %%
# Создадим столбец - разобьем owners на owners_low, owners_high

# %%
df["owners_low"] = pd.Series([0] * len(df), dtype="Int64")
df["owners_high"] = pd.Series([0] * len(df), dtype="Int64")
for i, val in enumerate(df.owners):
    df.at[i, "owners_low"], df.at[i, "owners_high"] = list(map(int, val.replace(',', '').split(' .. ')))

df.drop('owners', axis=1, inplace=True)
df.head()
# Out:
#      appid                              name         developer  \
# 0      730  Counter-Strike: Global Offensive             Valve
# 1  1172470                      Apex Legends           Respawn
# 2   578080               PUBG: BATTLEGROUNDS  PUBG Corporation
# 3  1623730                          Palworld        Pocketpair
# 4      440                   Team Fortress 2             Valve
#
#          publisher  score_rank  positive  negative  userscore  \
# 0            Valve         NaN   7642084   1173003          0
# 1  Electronic Arts         NaN    668053    326926          0
# 2    KRAFTON, Inc.         NaN   1520457   1037487          0
# 3       Pocketpair         NaN    358266     22443          0
# 4            Valve         NaN   1044264    117208          0
#
#    average_forever  average_2weeks  median_forever  median_2weeks  price  \
# 0            33852             708            6645            301      0
# ...

# %%
# Слишком много NaN -> удалим столбец
df[df.score_rank.isnull()].shape
df.drop('score_rank', axis=1, inplace=True)

# %%
# Добавление строки

# %%
new_row = {col: np.nan for col in df.columns}
new_row = {
    'appid': 1,
    'name': "test",
    'developer': "me",
    'publisher': "me",
    'positive': 2000,
    'negative': 0,
    'userscore': 100,
    'average_forever': 1000,
    'average_2weeks': 10000,
    'median_forever': 4000,
    'median_2weeks': 8000,
    'price': 999,
    'initialprice': 2,
    'discount': 99,
    'ccu': 30000,
    'owners_low': 10000,
    'owners_high': 20000
}

df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
df.tail()
# Out:
#          appid                        name              developer  \
# 9996    649600  Swords and Sandals 2 Redux  Whiskeybarrel Studios
# 9997   1122120                 STATIONflow              DMM GAMES
# 9998    424640    Karaski: What Goes Up...      Unbound Creations
# 9999    598060              Slasher's Keep        Damian Schloter
# 10000        1                        test                     me
#
#                publisher  positive  negative  userscore  average_forever  \
# 9996          eGames.com       429       117          0              333
# 9997           DMM GAMES       414        66          0              984
# 9998   Unbound Creations        51         8          0                0
# 9999     Damian Schloter      1791       355          0              423
# 10000                 me      2000         0        100             1000
#
#        average_2weeks  median_forever  median_2weeks  price  initialprice  \
# ...

# %%
df = df[df["name"] != "test"].copy()

# %%
# Удалим строки с бесплатными играми
df = df[df["price"] > 0].copy()

# %%
# Удалим дубликаты по appid
df.drop_duplicates(subset=['appid'], inplace=True)

# %%
df['appid'].unique
# Out:
# <bound method Series.unique of 3       1623730
# 5       1938090
# 6       1063730
# 7       2358720
# 9           550
#          ...
# 9995     444720
# 9996     649600
# 9997    1122120
# 9998     424640
# 9999     598060
# Name: appid, Length: 7889, dtype: int64>

# %%
# Самые дорогие приложения steam
df.sort_values('price', ascending=False).head()
# Out:
#         appid                             name                      developer  \
# 4836  1325400  VEGAS Pro 18 Edit Steam Edition            MAGIX Software GmbH
# 7176   279280                         Ohmicide                      Ohm Force
# 4579   248170             Clickteam Fusion 2.5                      Clickteam
# 8603   837510              Pixel Game Maker MV  Gotcha Gotcha Games, KADOKAWA
# 8996   741390       最強の囲碁 ～名人への道～ / Igo Meijin          UNBALANCE Corporation
#
#                   publisher  positive  negative  userscore  average_forever  \
# 4836    MAGIX Software GmbH       478      1859          0             6020
# 7176              Ohm Force         1         1          0                0
# 4579              Clickteam      1661       203          0             5745
# 8603    Gotcha Gotcha Games       399       176          0              311
# 8996  UNBALANCE Corporation         3         1          0                0
#
# ...

# %% [markdown]
# ## Визуализация

# %%
plt.hist(df.price, bins=200)
plt.title("Гистограмма: price")
plt.xlabel("price")
plt.ylabel("count")
plt.show()

# %%
sns.kdeplot((df.owners_high - df.owners_low) / 2, fill=True)
plt.title("KDE: ~owners")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(data=df, x="median_2weeks", y="owners_low", alpha=0.35)
plt.title("Scatter: owners_low vs initialprice")
plt.show()

# %%
sns.boxenplot(data=df.price)
plt.xticks(rotation=90)
plt.show()
